# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.chdir("./drive/MyDrive/git_project/AnomalyDetectionApp/src")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# install detectron2

# %%
# !git clone https://github.com/facebookresearch/detectron2.git
# Out:
# Cloning into 'detectron2'...
# remote: Enumerating objects: 15263, done.
# remote: Counting objects: 100% (284/284), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 15263 (delta 149), reused 174 (delta 108), pack-reused 14979
# Receiving objects: 100% (15263/15263), 6.29 MiB | 9.59 MiB/s, done.
# Resolving deltas: 100% (11016/11016), done.
# Updating files: 100% (820/820), done.

# %%
# %cd detectron2
# Out:
# /content/drive/MyDrive/git_project/AnomalyDetectionApp/src/detectron2

# %%
# !git reset --hard 7d2e68dbe452fc422268d40ac185ea2609affca8
# Out:
# HEAD is now at 7d2e68d Pin omegaconf, as latest release conflicts with hydra-core

# %%
# !pwd
# Out:
# /content/drive/MyDrive/git_project/Segmentation/src/detectron2
